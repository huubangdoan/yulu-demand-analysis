# %%
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"../data/raw/yulu_bike_sharing_dataset.csv")
df_clean=pd.read_csv(r"../data/processed/yulu_bike_remove_outliers.csv")
cols=df.columns.to_list()
label_col=["datetime", "season", "holiday", "workingday", "weather"]
continuous_col=[i for i in cols if i not in label_col]

# %% [markdown]
# # Check 4 assumption before parametric test

# %%
model = ols('count ~ C(holiday)', data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.3166
# Date:                Wed, 26 Aug 2026   Prob (F-statistic):              0.574
# Time:                        14:00:38   Log-Likelihood:                -72045.
# No. Observations:               10886   AIC:                         1.441e+05
# Df Residuals:                   10884   BIC:                         1.441e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         191.7417      1.762    108.847      0.000     188.289     195.195
# C(holiday)[T.1]    -5.8638     10.422     -0.563      0.574     -26.293      14.565
# ==============================================================================
# Omnibus:                     2063.430   Durbin-Watson:                   0.316
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3559.504
# Skew:                           1.242   Prob(JB):                         0.00
# Kurtosis:                       4.297   Cond. No.                         6.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
